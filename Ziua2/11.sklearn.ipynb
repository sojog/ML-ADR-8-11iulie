# %%
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
make_regression(n_samples=3, n_features=1, n_targets=1)
# Out:
# (array([[-0.84461433],
#         [-0.74145666],
#         [ 1.22768506]]),
#  array([-59.41998603, -52.16267648,  86.36963219]))

# %%
make_regression(n_samples=4, n_features=1, n_targets=1)
# Out:
# (array([[-0.01129624],
#         [ 0.01455032],
#         [-0.67306609],
#         [ 1.42933036]]),
#  array([ -0.8727081 ,   1.12410772, -51.99875766, 110.42511918]))

# %%
make_regression(n_samples=3, n_features=2, n_targets=1)
# Out:
# (array([[-0.04292144, -0.38856981],
#         [-0.07986257, -1.78964595],
#         [ 0.80179542,  0.97325634]]),
#  array([ -35.90511205, -163.82422806,   99.03550854]))

# %%
x, y = make_regression(n_samples=3, n_features=1, n_targets=1)

# %%
x, y
# Out:
# (array([[0.5237618 ],
#         [0.39356801],
#         [0.3991675 ]]),
#  array([51.97761981, 39.05731228, 39.61300071]))

# %%
x, y = make_regression(n_samples=10, n_features=1, n_targets=1)
plt.scatter(x, y)

# %%
x, y = make_regression(n_samples=10, n_features=1, n_targets=1)
plt.scatter(x, y)
plt.plot(x, y)

# %%
x, y = make_regression(n_samples=10, n_features=1, n_targets=1, noise=0)
plt.scatter(x, y)
plt.plot(x, y)

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.predict([[2.5]])
# Out:
# array([114.59629603])

# %%
model.predict([[2.5], [3], [10]])
# Out:
# array([114.59629603, 137.51555524, 458.38518413])

# %%
x, y = make_regression(n_samples=100, n_features=1, n_targets=1, noise=20)
plt.scatter(x, y)
# plt.plot(x, y)

# %%
linear_model = LinearRegression()
linear_model
# Out:
# LinearRegression()

# %%
linear_model.fit(x, y)
# Out:
# LinearRegression()

# %%
valori_de_verificare = np.random.randint(-2, 2, 10)
valori_de_verificare
# Out:
# array([ 0, -1,  1, -2,  0,  1,  1, -1, -1, -2])

# %%
valori_de_verificare = valori_de_verificare.reshape((-1, 1))

# %%
linear_model.predict(valori_de_verificare)
# Out:
# array([   0.77295832,  -92.66673357,   94.21265021, -186.10642545,
#           0.77295832,   94.21265021,   94.21265021,  -92.66673357,
#         -92.66673357, -186.10642545])

# %%
splitted = train_test_split(x, y)
print(len(splitted))
# Out:
# 4

# %%
splitted = train_test_split(x, y)
print(len(splitted))

for data in splitted:
    print(len(data))
# Out:
# 4
# 75
# 25
# 75
# 25

# %%
x_train, x_test, y_train, y_test =  train_test_split(x, y)

# %% [markdown]
# # model.fit (x_train, y_train)
# # model.predict(x_test, y_test)
