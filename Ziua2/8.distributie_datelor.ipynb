# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(2, 7)
y = x

plt.scatter(x, y)
plt.show()

# %%
x = np.arange(2, 7)
y = x

plt.scatter(x, y)
plt.plot(x, y)
plt.show()

# %%
x = np.arange(2, 7)
y = x


plt.plot(x, y)
plt.scatter(x, y, color="r")
plt.show()

# %%
np.arange(2, 7)
# Out:
# array([2, 3, 4, 5, 6])

# %%
x = np.array([2, 3, 4, 5, 6])
y = np.array([2, 4, 5, 5, 6])


plt.plot(x, y)
plt.scatter(x, y, color="r")
plt.show()

# %%
x = np.array([45, 60, 70])
y = np.array([65, 80, 90])


plt.xlabel("Suprafata (mp)")
plt.ylabel("Pret (mii de euro)")
plt.plot(x, y)
plt.scatter(x, y, color="r")
plt.show()

# %%
x = np.array([45, 60, 70, 55])
y = np.array([65, 82, 90, 70])


plt.xlabel("Suprafata (mp)")
plt.ylabel("Pret (mii de euro)")
plt.plot(x, y)
plt.scatter(x, y, color="r")
plt.show()

# %%
x = np.array([45, 55, 60, 70])
y = np.array([65, 70, 82, 90])


plt.xlabel("Suprafata (mp)")
plt.ylabel("Pret (mii de euro)")
plt.plot(x, y)
plt.scatter(x, y, color="r")
plt.show()

# %%
apartamente = [(45, 65), (55, 70), (60, 82), (70, 90)]

suprafete = [ i[0] for i in apartamente]
preturi =  [ i[1] for i in apartamente]




plt.xlabel("Suprafata (mp)")
plt.ylabel("Pret (mii de euro)")
plt.plot(x, y)
plt.scatter(x, y, color="r")
plt.show()

# %%
apartamente = [(45, 65), (90, 130), (55, 70), (60, 82), (70, 90)]

suprafete = [ i[0] for i in apartamente]
preturi =  [ i[1] for i in apartamente]

plt.xlabel("Suprafata (mp)")
plt.ylabel("Pret (mii de euro)")
plt.plot(suprafete, preturi)
plt.scatter(suprafete, preturi, color="r")
plt.show()

# %%
apartamente = [(45, 65),  (55, 70), (60, 82), (70, 90), (90, 130)]


suprafete = [ i[0] for i in apartamente]
preturi =  [ i[1] for i in apartamente]

plt.xlabel("Suprafata (mp)")
plt.ylabel("Pret (mii de euro)")
plt.plot(suprafete, preturi)
plt.scatter(suprafete, preturi, color="r")
plt.show()

# %%
suprafete
# Out:
# [45, 55, 60, 70, 90]

# %%
def functie_identitate(x):
    a = 1.4
    b = 0 
    return a * x + b

# %%
preziceri_preturi = [ functie_identitate(s)  for s in suprafete]
preziceri_preturi
# Out:
# [62.99999999999999, 77.0, 84.0, 98.0, 125.99999999999999]

# %%
apartamente = [(45, 65),  (55, 70), (60, 82), (70, 90), (90, 130)]


suprafete = [ i[0] for i in apartamente]
preturi =  [ i[1] for i in apartamente]

plt.xlabel("Suprafata (mp)")
plt.ylabel("Pret (mii de euro)")
plt.plot(suprafete, preturi)
plt.scatter(suprafete, preturi, color="r")


plt.plot(suprafete, preziceri_preturi, color="pink")

plt.show()

# %%
apartamente = [(45, 65_000),  (55, 70_000), (60, 82_000), (70, 90_000), (90, 130_000)]


suprafete = [ i[0] for i in apartamente]
preturi =  [ i[1] for i in apartamente]

plt.xlabel("Suprafata (mp)")
plt.ylabel("Pret (mii de euro)")
plt.plot(suprafete, preturi)
plt.scatter(suprafete, preturi, color="r")


def functie_identitate(x):
    a = 1.4 * 1000
    b = 0 
    return a * x + b 

# preziceri_preturi = [ functie_identitate(s)  for s in suprafete]
preziceri_preturi = list(map(functie_identitate, suprafete))

plt.plot(suprafete, preziceri_preturi, color="pink")

plt.show()

# %%
suprafata = 82.5
functie_identitate(suprafata)
# Out:
# 115500.0

# %%
apartamente = [(45, 65_000),  (55, 70_000), (60, 82_000), (70, 90_000), (90, 130_000)]


suprafete = [ i[0] for i in apartamente]
preturi =  [ i[1] for i in apartamente]

plt.xlabel("Suprafata (mp)")
plt.ylabel("Pret (mii de euro)")
# plt.plot(suprafete, preturi)
plt.scatter(suprafete, preturi, color="r")


def functie_solutie_1(x):
    a = 1.4 * 1000
    b = 0 
    return a * x + b 

# preziceri_preturi = [ functie_identitate(s)  for s in suprafete]
preziceri_preturi1 = list(map(functie_solutie_1, suprafete))



def functie_solutie_2(x):
    a = 1.3 * 1000
    b = 0 
    return a * x + b 

preziceri_preturi1 = list(map(functie_solutie_1, suprafete))
preziceri_preturi2 = list(map(functie_solutie_2, suprafete))

plt.plot(suprafete, preziceri_preturi1, color="pink")
plt.plot(suprafete, preziceri_preturi2, color="green")

plt.show()

# %%
from scipy import stats

# %%
obiect = stats.linregress(suprafete, preturi)
obiect.slope, obiect.intercept
# Out:
# (np.float64(1476.068376068376), np.float64(-7068.376068376063))

# %%
slope, intercept, *restul = stats.linregress(suprafete, preturi)
slope, intercept
# Out:
# (np.float64(1476.068376068376), np.float64(-7068.376068376063))

# %%
def functie_perfecta(x):
    a = slope # 1476.068376068376
    b = intercept -7068.376068376063
    return a * x + b

# %%
apartamente = [(45, 65_000),  (55, 70_000), (60, 82_000), (70, 90_000), (90, 130_000)]


suprafete = [ i[0] for i in apartamente]
preturi =  [ i[1] for i in apartamente]

plt.xlabel("Suprafata (mp)")
plt.ylabel("Pret (mii de euro)")
# plt.plot(suprafete, preturi)
plt.scatter(suprafete, preturi, color="r")


def functie_solutie_1(x):
    a = 1.4 * 1000
    b = 0 
    return a * x + b 

# preziceri_preturi = [ functie_identitate(s)  for s in suprafete]
preziceri_preturi1 = list(map(functie_solutie_1, suprafete))



def functie_solutie_2(x):
    a = 1.3 * 1000
    b = 0 
    return a * x + b 

def functie_perfecta(x):
    a = slope # 1476.068376068376
    b = intercept #-7068.376068376063
    return a * x + b 


preziceri_preturi1 = list(map(functie_solutie_1, suprafete))
preziceri_preturi2 = list(map(functie_solutie_2, suprafete))

preziceri_preturi_varianta_cea_mai_buna = list(map(functie_perfecta, suprafete))

plt.plot(suprafete, preziceri_preturi1, color="pink")
plt.plot(suprafete, preziceri_preturi2, color="green")

plt.plot(suprafete, preziceri_preturi_varianta_cea_mai_buna, color="black")

plt.show()

# %%
apartamente = [(45, 65),  (55, 70), (60, 82), (70, 90), (90, 130)]


suprafete = [ i[0] for i in apartamente]
preturi =  [ i[1] for i in apartamente]

plt.xlabel("Suprafata (mp)")
plt.ylabel("Pret (mii de euro)")
# plt.plot(suprafete, preturi)
plt.scatter(suprafete, preturi, color="r")


def functie_solutie_1(x):
    a = 1.4 
    b = 0 
    return a * x + b 

# preziceri_preturi = [ functie_identitate(s)  for s in suprafete]
preziceri_preturi1 = list(map(functie_solutie_1, suprafete))



def functie_solutie_2(x):
    a = 1.3 
    b = 0 
    return a * x + b 


slope, intercept, *restul = stats.linregress(suprafete, preturi)
slope, intercept

def functie_perfecta(x):
    a = slope # 1476.068376068376
    b = intercept #-7068.376068376063
    return a * x + b 


preziceri_preturi1 = list(map(functie_solutie_1, suprafete))
preziceri_preturi2 = list(map(functie_solutie_2, suprafete))

preziceri_preturi_varianta_cea_mai_buna = list(map(functie_perfecta, suprafete))



plt.plot(suprafete, preziceri_preturi1, color="pink")
plt.plot(suprafete, preziceri_preturi2, color="green")

plt.plot(suprafete, preziceri_preturi_varianta_cea_mai_buna, color="black")

plt.show()
