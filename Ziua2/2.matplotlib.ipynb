# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image = mpimg.imread("output.png")
type(image)
# Out:
# numpy.ndarray

# %%
figure, axis = plt.subplots()
figure

# %%
figure, axis = plt.subplots()
image = mpimg.imread("output.png")
axis.imshow(image)

# %%
figure, axis = plt.subplots()
image = mpimg.imread("Milan2007/Serginho.png")
axis.imshow(image)
